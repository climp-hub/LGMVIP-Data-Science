# %% [markdown]
# <a href="https://colab.research.google.com/github/climp-hub/LGMVIP-Data-Science/blob/main/ImageToSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LGMVIP TASK: Image to Pencil Sketch

# %%
#Importing Libraries
from PIL import Image
from IPython.display import display
import cv2

# %% [markdown]
# Loading Image

# %%
img = cv2.imread('/content/avatar860922148-0.jpg', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F390C09B4D0>

# %% [markdown]
# Converting Image to Grey Scale

# %%
img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(img_grey))
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7F390BFBB690>

# %% [markdown]
# Inverting the Image

# %%
img_inv = cv2.bitwise_not(img_grey)
display(Image.fromarray(img_inv))
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7F390C03E610>

# %% [markdown]
# Smoothing Image

# %%
img_smooth = cv2.GaussianBlur(img_inv, (5,5), 0, 0)
display(Image.fromarray(img_smooth))
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7F390BF291D0>

# %% [markdown]
# Inverting Image to sketch

# %%
def dodge(img_grey, img_smooth):
  img_smooth_inv = 255 - img_smooth
  return cv2.divide(img_grey, img_smooth_inv, scale=256.0)

# %%
img_final = dodge(img_grey, img_smooth)
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7F391A6B70D0>

# %% [markdown]
# Comparing with Original vs Sketch

# %%
display(Image.fromarray(img))
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F390BF3F3D0>
# <PIL.Image.Image image mode=L size=640x640 at 0x7F390BF3FE90>
